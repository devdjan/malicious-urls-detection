# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# save filepath to variable for easier acess

# %%
df = pd.read_csv('../data/malicious_urls.csv')

# %%
df.head()
# Out:
#    token_count  rank_host  rank_country  ASNno  sec_sen_word_cnt  \
# 0            3          1             1  15169                 0
# 1            3          2             2  32934                 0
# 2            3          3             3  15169                 0
# 3            3          4             4  36647                 0
# 4            3          6             1  23724                 0
#
#    avg_token_length  No_of_dots  malicious  Length_of_url  avg_path_token  \
# 0          4.333333           1          0             17             0.0
# 1          5.000000           1          0             19             0.0
# 2          4.666667           1          0             18             0.0
# 3          4.000000           1          0             16             0.0
# 4          4.000000           1          0             16             0.0
#
#        ...        safebrowsing                  URL          host  \
# 0      ...                   0    http://google.com    google.com
# 1      ...                   0  http://facebook.com  facebook.com
# 2      ...                   0   http://youtube.com   youtube.com
# 3      ...                   0     http://yahoo.com     yahoo.com
# 4      ...                   0     http://baidu.com     baidu.com
#
#   avg_domain_token_length path_token_count  path  largest_domain  \
# 0                     4.5                0   NaN               6
# 1                     5.5                0   NaN               8
# 2                     5.0                0   NaN               7
# 3                     4.0                0   NaN               5
# 4                     4.0                0   NaN               5
#
#   domain_token_count  largest_path  largest_token
# 0                  2             0              6
# 1                  2             0              8
# 2                  2             0              7
# 3                  2             0              5
# 4                  2             0              5
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#      token_count  rank_host  rank_country  ASNno  sec_sen_word_cnt  \
# 825            6         -1            -1  33626                 0
# 826            5         -1            -1  33626                 0
# 827            6         -1            -1   7506                 0
# 828            8         -1            -1     -1                 1
# 829            7         -1            -1     -1                 0
#
#      avg_token_length  No_of_dots  malicious  Length_of_url  avg_path_token  \
# 825          5.166667           2          1             38        4.000000
# 826          8.200000           2          1             47        8.000000
# 827          4.166667           2          1             32        3.000000
# 828          2.875000           2          1             32        2.000000
# 829          4.000000           2          1             36        3.333333
#
#          ...        safebrowsing  \
# 825      ...                   0
# 826      ...                   0
# 827      ...                   0
# 828      ...                   0
# 829      ...                   0
#
#                                                  URL                    host  \
# 825           http://carribespain.com/uk/persent.exe        carribespain.com
# 826  http://goldhostingservice.com/ujnegh6y73884.exe  goldhostingservice.com
# 827                 http://wedmoney.info/123/bot.exe           wedmoney.info
# 828                 http://login-srf.com/z/s/bot.exe           login-srf.com
# 829             http://nikonet-plus.com/vvn/nv_e.exe        nikonet-plus.com
#
#     avg_domain_token_length path_token_count                path  \
# 825                7.500000                3     /uk/persent.exe
# 826               10.500000                2  /ujnegh6y73884.exe
# 827                6.000000                3        /123/bot.exe
# 828                3.666667                4        /z/s/bot.exe
# 829                4.666667                3       /vvn/nv_e.exe
#
#      largest_domain domain_token_count  largest_path  largest_token
# 825              12                  2             7             12
# 826              18                  2            13             18
# 827               8                  2             3              8
# 828               5                  3             3              5
# 829               7                  3             4              7
#
# [5 rows x 22 columns]

# %%
df.describe(include='all')
# Out:
#         token_count     rank_host   rank_country          ASNno  \
# count    830.000000  8.300000e+02     830.000000     830.000000
# unique          NaN           NaN            NaN            NaN
# top             NaN           NaN            NaN            NaN
# freq            NaN           NaN            NaN            NaN
# mean       4.398795  2.441742e+05     424.784337   17527.222892
# std        2.501869  1.925838e+06    4998.967413   19872.596645
# min        1.000000 -1.000000e+00      -1.000000      -1.000000
# 25%        3.000000 -1.000000e+00      -1.000000    2545.750000
# 50%        3.000000  1.785000e+02      10.000000   14680.000000
# 75%        5.000000  3.867500e+02      94.750000   26830.500000
# max       31.000000  2.285824e+07  111203.000000  262421.000000
#
#         sec_sen_word_cnt  avg_token_length  No_of_dots   malicious  \
# count         830.000000        830.000000  830.000000  830.000000
# unique               NaN               NaN         NaN         NaN
# top                  NaN               NaN         NaN         NaN
# freq                 NaN               NaN         NaN         NaN
# mean            0.026506          4.800639    1.531325    0.363855
# std             0.194672          1.304978    1.036537    0.481398
# min             0.000000          2.333333    0.000000    0.000000
# 25%             0.000000          4.000000    1.000000    0.000000
# 50%             0.000000          4.666667    1.000000    0.000000
# 75%             0.000000          5.364583    2.000000    1.000000
# max             2.000000         15.166667   13.000000    1.000000
#
#         Length_of_url  avg_path_token      ...        safebrowsing  \
# count      830.000000      830.000000      ...          830.000000
# unique            NaN             NaN      ...                 NaN
# top               NaN             NaN      ...                 NaN
# freq              NaN             NaN      ...                 NaN
# mean        27.487952        1.518593      ...            0.063855
# std         21.216825        2.408016      ...            0.244643
# min          8.000000        0.000000      ...            0.000000
# 25%         17.000000        0.000000      ...            0.000000
# 50%         20.000000        0.000000      ...            0.000000
# 75%         32.750000        3.666667      ...            0.000000
# max        281.000000       16.750000      ...            1.000000
#
#                       URL        host avg_domain_token_length  \
# count                 830         830              830.000000
# unique                829         686                     NaN
# top     http://google.com  oxdiet.com                     NaN
# freq                    2           4                     NaN
# mean                  NaN         NaN                5.376363
# std                   NaN         NaN                1.998285
# min                   NaN         NaN                0.000000
# 25%                   NaN         NaN                4.000000
# 50%                   NaN         NaN                5.000000
# 75%                   NaN         NaN                6.500000
# max                   NaN         NaN               13.000000
#
#        path_token_count        path  largest_domain domain_token_count  \
# count        830.000000         280      830.000000         830.000000
# unique              NaN         105             NaN                NaN
# top                 NaN  /pcdef.exe             NaN                NaN
# freq                NaN          35             NaN                NaN
# mean           0.987952         NaN        8.304819           2.327711
# std            1.700025         NaN        4.677008           0.956763
# min            0.000000         NaN        0.000000           0.000000
# 25%            0.000000         NaN        6.000000           2.000000
# 50%            0.000000         NaN        7.000000           2.000000
# 75%            2.000000         NaN       10.000000           2.000000
# max           18.000000         NaN       62.000000          14.000000
#
#         largest_path  largest_token
# count     830.000000     830.000000
# unique           NaN            NaN
# top              NaN            NaN
# freq             NaN            NaN
# mean        2.280723       8.916867
# std         4.445840       6.141208
# min         0.000000       4.000000
# 25%         0.000000       6.000000
# 50%         0.000000       7.000000
# 75%         5.000000      10.750000
# max        34.000000      71.000000
#
# [11 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['token_count', 'rank_host', 'rank_country', 'ASNno', 'sec_sen_word_cnt',
#        'avg_token_length', 'No_of_dots', 'malicious', 'Length_of_url',
#        'avg_path_token', 'IPaddress_presence', 'Length_of_host',
#        'safebrowsing', 'URL', 'host', 'avg_domain_token_length',
#        'path_token_count', 'path', 'largest_domain', 'domain_token_count',
#        'largest_path', 'largest_token'],
#       dtype='object')

# %%
df.
